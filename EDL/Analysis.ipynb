# %%
import glob
import csv
from collections import defaultdict, Counter

# %%
# PICK A YEAR

year='2015_train'
#year='2015_test'
#year='2016'
#year='2017'

# %% [markdown]
# ### 1. Analysis of the gold data

# %%
edl_data_dir='data'
analysis_dir='analysis'

# %%
edl2016_file='%s/edl2016_gold_data/data/tac_kbp_2016_edl_evaluation_gold_standard_entity_mentions.tab' % edl_data_dir
edl2015_test='%s/edl2015_testing_data/data/tac_kbp_2015_tedl_evaluation_gold_standard_entity_mentions.tab' % edl_data_dir
edl2015_train='%s/edl2015_training_data_2.0/data/tac_kbp_2015_tedl_training_gold_standard_entity_mentions.tab' % edl_data_dir
edl2017_file='%s/LDC2017E25_TAC_KBP_2017_Evaluation_Source_Corpus/'

# %% [markdown]
# #### 1a. Investigation of variance

# %%
def is_nil(link):
    return link.startswith('NIL')

# %%
def extract_row_info(row):
    mid=row[1]
    form=row[2]
    
    doc_id=row[3].split(':')[0]
    collection=doc_id[:3]
    
    link=row[4]
    etype=row[5]
    mtype=row[6]
    
    return mid, form, doc_id, collection, link, etype, mtype

# %%
def analyze_file(rows):

    cnt_nils=0
    collections=defaultdict(int)
    nom_only=0
    nam_only=0
    
    cluster_nam_nom=defaultdict(list)
    
    nil_clusters=set()
    clusters_with_mentions=defaultdict(list)
    clusters_with_docs=defaultdict(list)
    form_to_meaning=defaultdict(set)

    for row in rows:

        mid, form, doc_id, collection, link, etype, mtype = extract_row_info(row)

        if collection not in {'ENG', 'NYT'}:
            continue
        form_to_meaning[form].add(link)
        collections[collection]+=1
        if is_nil(link) and etype=='PER':
            cnt_nils+=1
            nil_clusters.add(link)
            
            clusters_with_mentions[link].append(form)
            clusters_with_docs[link].append(doc_id)
            
            cluster_nam_nom[link].append(mtype)
            
    print('Count of docs per collection', collections)
    print('# Mentions of NILs = ', cnt_nils)
    print('# NIL clusters', len(nil_clusters))
    
    for link, nam_nom in cluster_nam_nom.items():
        if 'NAM' not in nam_nom:
            nom_only+=1
        elif 'NOM' not in nam_nom:
            nam_only+=1

    print('NOM only', nom_only)
    print('NAM only', nam_only)
        
    return nil_clusters, clusters_with_mentions, clusters_with_docs, form_to_meaning

# %%
def aggregate_per_cluster_size(clusters):
    agg_per_cluster_size=defaultdict(int)

    for l, ids in clusters.items():
        agg_per_cluster_size[len(ids)]+=1
    
    return agg_per_cluster_size

# %%
def print_largest_clusters(clusters, deduplicate=False, how_many=5):
    counts={}
    for link, ids in clusters.items():
        if deduplicate:
            ids=set(ids)
        counts[link]=len(ids)
    
    print('Deduplicated forms', deduplicate)
    for link, count in Counter(counts).most_common(2):
        print(link, count, set(clusters[link]))
    return

# %%
for file_to_open in [edl2015_train, edl2015_test, edl2016_file]:
    print(file_to_open)
    with open(file_to_open, 'r') as csvfile:
        rdrr = csv.reader(csvfile, delimiter='\t')

        nil_clusters, clusters_with_mentions, clusters_with_docs, form_to_meaning = analyze_file(rdrr)

        agg_per_cluster_size_men = aggregate_per_cluster_size(clusters_with_mentions)
        agg_per_cluster_size_doc = aggregate_per_cluster_size(clusters_with_docs)

        for dedup in [True, False]:
            print_largest_clusters(clusters_with_mentions, deduplicate=dedup)
    print()
# Out:
# data/edl2015_training_data_2.0/data/tac_kbp_2015_tedl_training_gold_standard_entity_mentions.tab
# Count of docs per collection defaultdict(<class 'int'>, {'ENG': 13545})
# # Mentions of NILs =  3574
# # NIL clusters 1800
# NOM only 140
# NAM only 1524
# Deduplicated forms True
# NIL03593 31 {'shit', 'vet', 'veteran', 'guy', 'victim', 'neighbor', 'killer', 'Eddie Routh', 'Muslim', 'child', 'Sympathizer', 'dude', 'Eddie Ray Routh', 'user', 'performer', 'guard', 'son', 'friend', 'asshole', 'doper', 'Dude', 'creep', 'Killer', 'sufferer', 'POS', 'Eddie', 'cretin', 'Routh', 'individual', 'Schizophrenic', 'man'}
# NIL00087 12 {'Gamadhere', 'terrorist', 'leader', 'mastermind', 'Mohamed Mohamud', 'Mohamed Kuno', 'Kuno', 'Dulyadayna', 'Mohamud', 'man', 'teacher', 'Dulyadin Gamadhere'}
# Deduplicated forms False
# NIL03593 125 {'shit', 'vet', 'veteran', 'guy', 'victim', 'neighbor', 'killer', 'Eddie Routh', 'Muslim', 'child', 'Sympathizer', 'dude', 'Eddie Ray Routh', 'user', 'performer', 'guard', 'son', 'friend', 'asshole', 'doper', 'Dude', 'creep', 'Killer', 'sufferer', 'POS', 'Eddie', 'cretin', 'Routh', 'individual', 'Schizophrenic', 'man'}
# NIL03657 55 {'Tsarnaev', 'Tamerlan Tsarnaev', 'Tamerlan', 'Black Hat', 'mover', 'brother'}
#
# data/edl2015_testing_data/data/tac_kbp_2015_tedl_evaluation_gold_standard_entity_mentions.tab
# Count of docs per collection defaultdict(<class 'int'>, {'ENG': 15645})
# # Mentions of NILs =  3986
# # NIL clusters 1537
# NOM only 197
# NAM only 1110
# Deduplicated forms True
# NIL00009 51 {'Roof', 'terrorist', 'gunman', 'loon', 'person', 'South Carolinian', 'guy', 'shooter', 'innocent', '21-year-old', 'defendant', 'drug-user', 'kid', 'author', 'killer', 'someone', 'murderer', 'child', 'lunatic', 'AryanBlood1488', 'supremacist', '4-year-old', 'recluse', 'boy', 'white supremacist', 'perpetrator', 'Dylann', 'son', 'suspect', 'Dylann Roofs', 'drop-out', 'monster', 'Suspect', 'TERRORIST', 'friend', 'loser', 'Dylann Storm Roof', 'Dylan roof', 'bastard', 'loner', 'stepson', 'Storm Roof', 'nephew', 'adult', '11-year-old', 'Felon', 'Dylann Roof', 'classmate', 'Dylan Roof', 'man', 'Christian'}
# NIL00231 23 {'terrorist', 'knight', 'Rezgui', 'gunman', 'attacker', 'tourist', 'shooter', 'Tunisian', 'killer', 'someone', 'Muslim', 'Abu Yahya al-Qayrawani', 'student', 'Seif Eddine Rezgu', 'Abu-Yahya AlQairwani', 'jihadi', 'hero', 'attackers', 'Seifeddine Rezgui', 'member', 'Knight', 'soldier', 'man'}
# Deduplicated forms False
# NIL00009 330 {'Roof', 'terrorist', 'gunman', 'loon', 'person', 'South Carolinian', 'guy', 'shooter', 'innocent', '21-year-old', 'defendant', 'drug-user', 'kid', 'author', 'killer', 'someone', 'murderer', 'child', 'lunatic', 'AryanBlood1488', 'supremacist', '4-year-old', 'recluse', 'boy', 'white supremacist', 'perpetrator', 'Dylann', 'son', 'suspect', 'Dylann Roofs', 'drop-out', 'monster', 'Suspect', 'TERRORIST', 'friend', 'loser', 'Dylann Storm Roof', 'Dylan roof', 'bastard', 'loner', 'stepson', 'Storm Roof', 'nephew', 'adult', '11-year-old', 'Felon', 'Dylann Roof', 'classmate', 'Dylan Roof', 'man', 'Christian'}
# NIL00132 85 {'CDI', 'person', 'victim', 'polyglot', 'MONGUNO', 'Monte', 'National Security Adviser', 'Babagana Monguno', 'fighter', 'General', 'nephew', 'Commander of Brigade', 'officer', 'Commandant', 'adviser', 'NSA', 'Chief', 'member', 'man', 'Adjutant', 'Monguno', 'Architect'}
#
# data/edl2016_gold_data/data/tac_kbp_2016_edl_evaluation_gold_standard_entity_mentions.tab
# Count of docs per collection defaultdict(<class 'int'>, {'ENG': 7199, 'NYT': 2032})
# # Mentions of NILs =  1466
# # NIL clusters 999
# NOM only 91
# NAM only 826
# Deduplicated forms True
# NIL00477 5 {'Salah Al Din Al-Hamwi', 'member', 'Al-Hamwi', 'Al- Hamwi', 'representative'}
# NIL00427 4 {'Patino', 'expert', 'Andres Patino', 'specialist'}
# Deduplicated forms False
# NIL01119 11 {'expert', 'Dirk Kotze', 'Kotze'}
# NIL00989 10 {'Wife', 'wife'}

# %% [markdown]
# #### 1b. Investigate ambiguity

# %%
for year in ['2015_train', '2015_test', '2016']:

    if year=='2015_train':
        file_to_open=edl2015_train
    elif year=='2015_test':
        file_to_open=edl2015_test
    else: # 2016
        file_to_open=edl2016_file
    
    print(file_to_open)
    with open(file_to_open, 'r') as csvfile:
        rdrr = csv.reader(csvfile, delimiter='\t')

        nil_clusters, clusters_with_mentions, clusters_with_docs, form_to_meaning = analyze_file(rdrr)
    
    
        ambiguous_all_file='%s/%s_ambiguous_all.tsv' % (analysis_dir, year)
        ambiguous_nils_file='%s/%s_ambiguous_nils.tsv' % (analysis_dir, year)
        ambiguous_nonnils_file='%s/%s_ambiguous_nonnils.tsv' % (analysis_dir, year)
        ambiguous_both_file='%s/%s_ambiguous_both.tsv' % (analysis_dir, year)

        c=0
        with open(ambiguous_all_file, 'w') as w:
            with open(ambiguous_nils_file, 'w') as w_n:
                with open(ambiguous_nonnils_file, 'w') as w_nn:
                    with open(ambiguous_both_file, 'w') as w_both:
                        w.write('\t'.join(['FORM','TOTAL', 'NILs', 'non-NILs']))
                        for form, meanings in form_to_meaning.items():
                            if len(meanings)>1:
                                nils=0
                                non_nils=0
                                for m in meanings:
                                    if is_nil(m):
                                        nils+=1
                                    else:
                                        non_nils+=1
                                print(form, len(meanings), 'total', nils, 'NILs', non_nils, 'non-NILs')   
                                c+=1
                                row='%s\t%d\t%d\t%d\n' % (form, len(meanings), nils, non_nils)
                                w.write(row)
                                if nils==0: # only non_nils
                                    w_nn.write(row)
                                elif non_nils==0: # only nils
                                    w_n.write(row)
                                else: # there are both
                                    w_both.write(row)
# Out:
# data/edl2015_training_data_2.0/data/tac_kbp_2015_tedl_training_gold_standard_entity_mentions.tab
# Count of docs per collection defaultdict(<class 'int'>, {'ENG': 13545})
# # Mentions of NILs =  3574
# # NIL clusters 1800
# NOM only 140
# NAM only 1524
# Whole Foods 2 total 1 NILs 1 non-NILs
# Natanz 2 total 1 NILs 1 non-NILs
# SE 2 total 1 NILs 1 non-NILs
# Constantia Kloof 2 total 1 NILs 1 non-NILs
# US District Court 2 total 1 NILs 1 non-NILs
# correspondent 3 total 3 NILs 0 non-NILs
# friend 14 total 11 NILs 3 non-NILs
# director 4 total 2 NILs 2 non-NILs
# member 5 total 3 NILs 2 non-NILs
# student 3 total 3 NILs 0 non-NILs
# teacher 2 total 2 NILs 0 non-NILs
# one 14 total 9 NILs 5 non-NILs
# spokesman 8 total 8 NILs 0 non-NILs
# Warren 2 total 1 NILs 1 non-NILs
# prosecutor 3 total 3 NILs 0 non-NILs
# Weinreb 2 total 2 NILs 0 non-NILs
# agent 2 total 2 NILs 0 non-NILs
# Miriam Conrad 2 total 2 NILs 0 non-NILs
# author 5 total 3 NILs 2 non-NILs
# baby 5 total 2 NILs 3 non-NILs
# son 11 total 8 NILs 3 non-NILs
# child 7 total 4 NILs 3 non-NILs
# woman 14 total 6 NILs 8 non-NILs
# Martin Richard 2 total 1 NILs 1 non-NILs
# Martin 2 total 1 NILs 1 non-NILs
# boy 4 total 1 NILs 3 non-NILs
# sister 3 total 2 NILs 1 non-NILs
# brother 12 total 7 NILs 5 non-NILs
# professor 2 total 2 NILs 0 non-NILs
# Bush 4 total 2 NILs 2 non-NILs
# worker 2 total 2 NILs 0 non-NILs
# witness 4 total 4 NILs 0 non-NILs
# daughter 11 total 9 NILs 2 non-NILs
# attorney 3 total 1 NILs 2 non-NILs
# Jeb 2 total 1 NILs 1 non-NILs
# lawyer 4 total 3 NILs 1 non-NILs
# uncle 3 total 3 NILs 0 non-NILs
# father 11 total 6 NILs 5 non-NILs
# dad 3 total 3 NILs 0 non-NILs
# socialite 2 total 2 NILs 0 non-NILs
# caretaker 2 total 2 NILs 0 non-NILs
# person 11 total 8 NILs 3 non-NILs
# man 29 total 14 NILs 15 non-NILs
# guard 3 total 3 NILs 0 non-NILs
# mayor 3 total 1 NILs 2 non-NILs
# rival 3 total 1 NILs 2 non-NILs
# husband 14 total 7 NILs 7 non-NILs
# secretary 2 total 1 NILs 1 non-NILs
# commander 2 total 1 NILs 1 non-NILs
# head 2 total 2 NILs 0 non-NILs
# chief 2 total 2 NILs 0 non-NILs
# girlfriend 3 total 2 NILs 1 non-NILs
# Ranger 2 total 2 NILs 0 non-NILs
# Minister 2 total 1 NILs 1 non-NILs
# wife 12 total 5 NILs 7 non-NILs
# journalist 8 total 6 NILs 2 non-NILs
# colleague 2 total 2 NILs 0 non-NILs
# national 2 total 2 NILs 0 non-NILs
# doctor 2 total 2 NILs 0 non-NILs
# academic 2 total 2 NILs 0 non-NILs
# Sean Collier 2 total 2 NILs 0 non-NILs
# officer 6 total 4 NILs 2 non-NILs
# model 2 total 1 NILs 1 non-NILs
# leader 16 total 4 NILs 12 non-NILs
# terrorist 4 total 1 NILs 3 non-NILs
# Mother 2 total 2 NILs 0 non-NILs
# mother 11 total 8 NILs 3 non-NILs
# lady 4 total 1 NILs 3 non-NILs
# mom 4 total 3 NILs 1 non-NILs
# Chechen 3 total 1 NILs 2 non-NILs
# Montana 2 total 1 NILs 1 non-NILs
# owner 3 total 3 NILs 0 non-NILs
# One 3 total 1 NILs 2 non-NILs
# boyfriend 2 total 1 NILs 1 non-NILs
# Syrian 2 total 1 NILs 1 non-NILs
# photographer 2 total 2 NILs 0 non-NILs
# citizen 2 total 2 NILs 0 non-NILs
# Mitchell 2 total 1 NILs 1 non-NILs
# blogger 2 total 2 NILs 0 non-NILs
# source 2 total 2 NILs 0 non-NILs
# driver 2 total 2 NILs 0 non-NILs
# reporter 5 total 5 NILs 0 non-NILs
# Widow 2 total 1 NILs 1 non-NILs
# widow 2 total 1 NILs 1 non-NILs
# Gulf Coast 2 total 1 NILs 1 non-NILs
# National Prosecuting Authority 2 total 1 NILs 1 non-NILs
# NPA 2 total 1 NILs 1 non-NILs
# boss 2 total 0 NILs 2 non-NILs
# ISIS 2 total 0 NILs 2 non-NILs
# Islamic State 2 total 0 NILs 2 non-NILs
# President 6 total 1 NILs 5 non-NILs
# Iraq 2 total 0 NILs 2 non-NILs
# Washington 3 total 0 NILs 3 non-NILs
# American 3 total 2 NILs 1 non-NILs
# United States 2 total 1 NILs 1 non-NILs
# NBC 2 total 0 NILs 2 non-NILs
# Britain 2 total 0 NILs 2 non-NILs
# White House 3 total 0 NILs 3 non-NILs
# Wall Street 2 total 0 NILs 2 non-NILs
# Kyle 2 total 0 NILs 2 non-NILs
# Republican 3 total 0 NILs 3 non-NILs
# Clinton 2 total 0 NILs 2 non-NILs
# Secretary of State 2 total 1 NILs 1 non-NILs
# New York Times 2 total 0 NILs 2 non-NILs
# New York 2 total 0 NILs 2 non-NILs
# Netanyahu 2 total 0 NILs 2 non-NILs
# minister 2 total 1 NILs 1 non-NILs
# victim 4 total 1 NILs 3 non-NILs
# president 13 total 0 NILs 13 non-NILs
# Katsina 2 total 0 NILs 2 non-NILs
# Garissa 3 total 1 NILs 2 non-NILs
# Israel 2 total 0 NILs 2 non-NILs
# US 2 total 1 NILs 1 non-NILs
# America 3 total 2 NILs 1 non-NILs
# Palestinian 2 total 0 NILs 2 non-NILs
# Palestine 2 total 0 NILs 2 non-NILs
# Egyptian 2 total 0 NILs 2 non-NILs
# immigrant 2 total 0 NILs 2 non-NILs
# foreign 2 total 0 NILs 2 non-NILs
# Gaza 2 total 0 NILs 2 non-NILs
# Times 2 total 0 NILs 2 non-NILs
# CNN 2 total 1 NILs 1 non-NILs
# Security Council 2 total 0 NILs 2 non-NILs
# Paralympian 2 total 0 NILs 2 non-NILs
# Pistorius 2 total 0 NILs 2 non-NILs
# Rambo 2 total 0 NILs 2 non-NILs
# European 2 total 0 NILs 2 non-NILs
# BBC 2 total 1 NILs 1 non-NILs
# hero 4 total 0 NILs 4 non-NILs
# figure 3 total 0 NILs 3 non-NILs
# guy 14 total 2 NILs 12 non-NILs
# star 3 total 0 NILs 3 non-NILs
# celebrity 2 total 0 NILs 2 non-NILs
# interviewer 2 total 1 NILs 1 non-NILs
# Steenkamp 3 total 2 NILs 1 non-NILs
# judge 6 total 5 NILs 1 non-NILs
# counterpart 2 total 0 NILs 2 non-NILs
# Russian 2 total 0 NILs 2 non-NILs
# British 3 total 0 NILs 3 non-NILs
# governor 5 total 0 NILs 5 non-NILs
# Lagos 2 total 0 NILs 2 non-NILs
# NBA 2 total 0 NILs 2 non-NILs
# democratic 2 total 0 NILs 2 non-NILs
# Egypt 2 total 0 NILs 2 non-NILs
# SEAL 2 total 0 NILs 2 non-NILs
# Boston 2 total 1 NILs 1 non-NILs
# sniper 2 total 1 NILs 1 non-NILs
# veteran 2 total 1 NILs 1 non-NILs
# individual 2 total 1 NILs 1 non-NILs
# warrior 2 total 0 NILs 2 non-NILs
# Iraqi 2 total 0 NILs 2 non-NILs
# girl 4 total 1 NILs 3 non-NILs
# Abdullah 2 total 0 NILs 2 non-NILs
# pilot 2 total 2 NILs 0 non-NILs
# Robert Godec 2 total 1 NILs 1 non-NILs
# diplomat 2 total 0 NILs 2 non-NILs
# official 8 total 7 NILs 1 non-NILs
# Gulf 2 total 0 NILs 2 non-NILs
# Ahmed Abdi Godane 2 total 1 NILs 1 non-NILs
# Westgate Mall 2 total 1 NILs 1 non-NILs
# actor 3 total 0 NILs 3 non-NILs
# Brad 2 total 1 NILs 1 non-NILs
# candidate 5 total 1 NILs 4 non-NILs
# Red Square 2 total 0 NILs 2 non-NILs
# Kremlin 3 total 0 NILs 3 non-NILs
# politician 3 total 0 NILs 3 non-NILs
# Tsarnaev 2 total 1 NILs 1 non-NILs
# Putin 2 total 0 NILs 2 non-NILs
# opponent 3 total 0 NILs 3 non-NILs
# KGB 2 total 1 NILs 1 non-NILs
# George A. O’Toole Jr. 2 total 1 NILs 1 non-NILs
# O’Toole 2 total 1 NILs 1 non-NILs
# Federal District Court 2 total 0 NILs 2 non-NILs
# Lingzi Lu 2 total 1 NILs 1 non-NILs
# NSA 2 total 1 NILs 1 non-NILs
# WS 2 total 1 NILs 1 non-NILs
# Bosnia 2 total 0 NILs 2 non-NILs
# USA 2 total 1 NILs 1 non-NILs
# Jessica Kensky 2 total 2 NILs 0 non-NILs
# Ireland 2 total 0 NILs 2 non-NILs
# Irish 2 total 0 NILs 2 non-NILs
# Killer 2 total 2 NILs 0 non-NILs
# Muslim 2 total 1 NILs 1 non-NILs
# killer 2 total 2 NILs 0 non-NILs
# government 4 total 0 NILs 4 non-NILs
# Supreme Court 2 total 0 NILs 2 non-NILs
# statesman 2 total 0 NILs 2 non-NILs
# MIT 2 total 0 NILs 2 non-NILs
# liberal 2 total 0 NILs 2 non-NILs
# Cameron 2 total 1 NILs 1 non-NILs
# Prime Minister 3 total 0 NILs 3 non-NILs
# Europe 2 total 0 NILs 2 non-NILs
# Czech 2 total 0 NILs 2 non-NILs
# gangster 2 total 0 NILs 2 non-NILs
# prisoner 2 total 1 NILs 1 non-NILs
# native 2 total 1 NILs 1 non-NILs
# ambassador 2 total 2 NILs 0 non-NILs
# Godane 2 total 1 NILs 1 non-NILs
# England 2 total 0 NILs 2 non-NILs
# SF 2 total 0 NILs 2 non-NILs
# MEP 2 total 0 NILs 2 non-NILs
# Barry 2 total 1 NILs 1 non-NILs
# Atlantic 2 total 0 NILs 2 non-NILs
# predator 2 total 0 NILs 2 non-NILs
# democrat 2 total 0 NILs 2 non-NILs
# Democrat 4 total 0 NILs 4 non-NILs
# socialist 2 total 0 NILs 2 non-NILs
# white house 2 total 0 NILs 2 non-NILs
# congress 2 total 0 NILs 2 non-NILs
# cheater 2 total 0 NILs 2 non-NILs
# Oval Office 2 total 0 NILs 2 non-NILs
# west 2 total 0 NILs 2 non-NILs
# first lady 2 total 0 NILs 2 non-NILs
# NY 2 total 0 NILs 2 non-NILs
# military 2 total 0 NILs 2 non-NILs
# muslim 2 total 0 NILs 2 non-NILs
# Castro 3 total 0 NILs 3 non-NILs
# loser 2 total 1 NILs 1 non-NILs
# WH 2 total 0 NILs 2 non-NILs
# iraq 2 total 0 NILs 2 non-NILs
# Paul 2 total 1 NILs 1 non-NILs
# Dude 2 total 2 NILs 0 non-NILs
# asshole 2 total 1 NILs 1 non-NILs
# POS 2 total 1 NILs 1 non-NILs
# dude 6 total 3 NILs 3 non-NILs
# sir 2 total 1 NILs 1 non-NILs
# taliban 2 total 0 NILs 2 non-NILs
# Government 2 total 0 NILs 2 non-NILs
# murderer 2 total 1 NILs 1 non-NILs
# Fox 2 total 1 NILs 1 non-NILs
# Anonymous 5 total 4 NILs 1 non-NILs
# Korea 2 total 0 NILs 2 non-NILs
# expert 2 total 2 NILs 0 non-NILs
# HRC 3 total 0 NILs 3 non-NILs
# OP 3 total 2 NILs 1 non-NILs
# spokesperson 2 total 2 NILs 0 non-NILs
# analyst 2 total 2 NILs 0 non-NILs
# the bear 2 total 2 NILs 0 non-NILs
# caravaggio2 2 total 2 NILs 0 non-NILs
# Thinkingabout 2 total 2 NILs 0 non-NILs
# karynnj 2 total 2 NILs 0 non-NILs
# Jefferson23 2 total 2 NILs 0 non-NILs
# Scootaloo 2 total 2 NILs 0 non-NILs
# guillaumeb 3 total 3 NILs 0 non-NILs
# leveymg 2 total 2 NILs 0 non-NILs
# Trajan 3 total 3 NILs 0 non-NILs
# jwirr 2 total 2 NILs 0 non-NILs
# Guest 2 total 2 NILs 0 non-NILs
# Darth_Harper 2 total 2 NILs 0 non-NILs
# IceSpear 2 total 2 NILs 0 non-NILs
# Ebsy 2 total 2 NILs 0 non-NILs
# Blackchampion 2 total 2 NILs 0 non-NILs
# Nobody 4 total 4 NILs 0 non-NILs
# dridowu 2 total 2 NILs 0 non-NILs
# idiot 2 total 2 NILs 0 non-NILs
# BluRidgeMNT 2 total 2 NILs 0 non-NILs
# Poop_in_my_Vulva 3 total 3 NILs 0 non-NILs
# dox_teh_authoritahs 2 total 2 NILs 0 non-NILs
# Reluire 3 total 3 NILs 0 non-NILs
# zippity.doodah 3 total 3 NILs 0 non-NILs
# LockheedSpooky 2 total 2 NILs 0 non-NILs
# bro 4 total 4 NILs 0 non-NILs
# Cha 2 total 2 NILs 0 non-NILs
# Jamaal510 2 total 2 NILs 0 non-NILs
# djean111 2 total 2 NILs 0 non-NILs
# AlbertCat 2 total 2 NILs 0 non-NILs
# B Calm 2 total 2 NILs 0 non-NILs
# tularetom 2 total 2 NILs 0 non-NILs
# VanillaRhapsody 2 total 2 NILs 0 non-NILs
# joshcryer 2 total 2 NILs 0 non-NILs
# mylye2222 2 total 2 NILs 0 non-NILs
# Hekate 2 total 2 NILs 0 non-NILs
# cali 3 total 3 NILs 0 non-NILs
# operative 2 total 2 NILs 0 non-NILs
# leftofcool 2 total 2 NILs 0 non-NILs
# msanthrope 3 total 3 NILs 0 non-NILs
# William769 3 total 3 NILs 0 non-NILs
# Gothmog 2 total 2 NILs 0 non-NILs
# Adrahil 2 total 2 NILs 0 non-NILs
# Rex 2 total 2 NILs 0 non-NILs
# TheDemSocialist 2 total 2 NILs 0 non-NILs
# poster 2 total 2 NILs 0 non-NILs
# DobermanPincher 2 total 2 NILs 0 non-NILs
# JonLP24 2 total 2 NILs 0 non-NILs
# InAbLuEsTaTe 2 total 2 NILs 0 non-NILs
# hifiguy 2 total 2 NILs 0 non-NILs
# Summertime 2 total 2 NILs 0 non-NILs
# Joseph the Second 2 total 2 NILs 0 non-NILs
# Barcanista 2 total 2 NILs 0 non-NILs
# barcanista 2 total 2 NILs 0 non-NILs
# adioolayi 3 total 3 NILs 0 non-NILs
# omenka 2 total 2 NILs 0 non-NILs
# [deleted] 6 total 6 NILs 0 non-NILs
# RollerRagerMD 2 total 2 NILs 0 non-NILs
# Law-Hopeful 2 total 2 NILs 0 non-NILs
# Aj12 4 total 4 NILs 0 non-NILs
# Pitbull 2 total 2 NILs 0 non-NILs
# snooper2 2 total 2 NILs 0 non-NILs
# BainsBane 2 total 2 NILs 0 non-NILs
# Bluenorthwest 2 total 2 NILs 0 non-NILs
# samsingh 2 total 2 NILs 0 non-NILs
# OKNancy 2 total 2 NILs 0 non-NILs
# riversedge 2 total 2 NILs 0 non-NILs
# data/edl2015_testing_data/data/tac_kbp_2015_tedl_evaluation_gold_standard_entity_mentions.tab
# Count of docs per collection defaultdict(<class 'int'>, {'ENG': 15645})
# # Mentions of NILs =  3986
# # NIL clusters 1537
# NOM only 197
# NAM only 1110
# man 38 total 27 NILs 11 non-NILs
# Bush 4 total 0 NILs 4 non-NILs
# Secretary of State 2 total 1 NILs 1 non-NILs
# brother 9 total 7 NILs 2 non-NILs
# National Security Adviser 5 total 4 NILs 1 non-NILs
# Clinton 2 total 0 NILs 2 non-NILs
# America 2 total 0 NILs 2 non-NILs
# Prince 4 total 3 NILs 1 non-NILs
# guy 18 total 12 NILs 6 non-NILs
# bastard 2 total 1 NILs 1 non-NILs
# Republican 8 total 2 NILs 6 non-NILs
# vice-president 2 total 0 NILs 2 non-NILs
# leader 19 total 7 NILs 12 non-NILs
# British 3 total 0 NILs 3 non-NILs
# NSA 2 total 1 NILs 1 non-NILs
# UK 3 total 0 NILs 3 non-NILs
# Britain 2 total 0 NILs 2 non-NILs
# Muslim 3 total 2 NILs 1 non-NILs
# member 20 total 13 NILs 7 non-NILs
# fella 3 total 3 NILs 0 non-NILs
# gunman 6 total 6 NILs 0 non-NILs
# muslim 2 total 1 NILs 1 non-NILs
# ISIS 2 total 0 NILs 2 non-NILs
# terrorist 2 total 2 NILs 0 non-NILs
# Queen 3 total 1 NILs 2 non-NILs
# woman 12 total 9 NILs 3 non-NILs
# wife 11 total 9 NILs 2 non-NILs
# Washington 3 total 0 NILs 3 non-NILs
# president 37 total 15 NILs 22 non-NILs
# second 2 total 1 NILs 1 non-NILs
# Paul 2 total 0 NILs 2 non-NILs
# father 9 total 6 NILs 3 non-NILs
# executive 2 total 0 NILs 2 non-NILs
# advisor 2 total 0 NILs 2 non-NILs
# adviser 3 total 1 NILs 2 non-NILs
# POTUS 3 total 0 NILs 3 non-NILs
# Iraq 2 total 0 NILs 2 non-NILs
# son 18 total 11 NILs 7 non-NILs
# another 3 total 2 NILs 1 non-NILs
# Democrat 6 total 1 NILs 5 non-NILs
# Fenton 2 total 2 NILs 0 non-NILs
# Gov. 19 total 19 NILs 0 non-NILs
# Larry Hogan 6 total 6 NILs 0 non-NILs
# American 3 total 1 NILs 2 non-NILs
# mayor 6 total 3 NILs 3 non-NILs
# a351 2 total 2 NILs 0 non-NILs
# Police Commissioner 6 total 5 NILs 1 non-NILs
# Mayor 21 total 20 NILs 1 non-NILs
# New York 2 total 0 NILs 2 non-NILs
# Charleston 2 total 0 NILs 2 non-NILs
# someone 7 total 4 NILs 3 non-NILs
# Dylann Roof 2 total 2 NILs 0 non-NILs
# shooter 5 total 5 NILs 0 non-NILs
# Roof 2 total 2 NILs 0 non-NILs
# Tsipras 2 total 1 NILs 1 non-NILs
# Prime Minister 19 total 17 NILs 2 non-NILs
# prime minister 6 total 2 NILs 4 non-NILs
# parliament 2 total 0 NILs 2 non-NILs
# colleague 4 total 3 NILs 1 non-NILs
# friend 18 total 15 NILs 3 non-NILs
# KTM 2 total 0 NILs 2 non-NILs
# one 29 total 17 NILs 12 non-NILs
# dude 4 total 3 NILs 1 non-NILs
# Russia 2 total 0 NILs 2 non-NILs
# England 2 total 0 NILs 2 non-NILs
# Moscow 2 total 0 NILs 2 non-NILs
# Crimea 3 total 2 NILs 1 non-NILs
# [deleted] 2 total 2 NILs 0 non-NILs
# Canadian 2 total 1 NILs 1 non-NILs
# idiot 5 total 4 NILs 1 non-NILs
# person 9 total 8 NILs 1 non-NILs
# CH 2 total 0 NILs 2 non-NILs
# Palestinian 2 total 0 NILs 2 non-NILs
# Senator 6 total 3 NILs 3 non-NILs
# turd 2 total 1 NILs 1 non-NILs
# south 3 total 1 NILs 2 non-NILs
# senator 4 total 0 NILs 4 non-NILs
# Sen. 13 total 13 NILs 0 non-NILs
# South 5 total 1 NILs 4 non-NILs
# Southern 2 total 0 NILs 2 non-NILs
# Senate 2 total 0 NILs 2 non-NILs
# NY 2 total 0 NILs 2 non-NILs
# Warner 2 total 0 NILs 2 non-NILs
# English 3 total 0 NILs 3 non-NILs
# UEFA 2 total 0 NILs 2 non-NILs
# FA 2 total 0 NILs 2 non-NILs
# chair 2 total 1 NILs 1 non-NILs
# Path_Finder 2 total 2 NILs 0 non-NILs
# President 85 total 76 NILs 9 non-NILs
# Lee 2 total 0 NILs 2 non-NILs
# North 6 total 1 NILs 5 non-NILs
# South Carolinian 2 total 2 NILs 0 non-NILs
# One 8 total 3 NILs 5 non-NILs
# General 18 total 17 NILs 1 non-NILs
# Founder 6 total 5 NILs 1 non-NILs
# Seamus L 2 total 2 NILs 0 non-NILs
# Tomdstone 2 total 2 NILs 0 non-NILs
# Cabinet 2 total 1 NILs 1 non-NILs
# head 6 total 3 NILs 3 non-NILs
# crai7 2 total 2 NILs 0 non-NILs
# Union 3 total 0 NILs 3 non-NILs
# Communist 2 total 0 NILs 2 non-NILs
# finance minister 2 total 2 NILs 0 non-NILs
# north 2 total 0 NILs 2 non-NILs
# Ireland 2 total 0 NILs 2 non-NILs
# Japan 2 total 0 NILs 2 non-NILs
# Finance Minister 5 total 4 NILs 1 non-NILs
# AIIB 2 total 2 NILs 0 non-NILs
# secretary 7 total 5 NILs 2 non-NILs
# Baruch 3 total 3 NILs 0 non-NILs
# Edward Snowden 2 total 1 NILs 1 non-NILs
# Justice 2 total 1 NILs 1 non-NILs
# Diamond Dragon 3 total 3 NILs 0 non-NILs
# hero 2 total 1 NILs 1 non-NILs
# DD 2 total 2 NILs 0 non-NILs
# star 2 total 0 NILs 2 non-NILs
# GamerGal 2 total 2 NILs 0 non-NILs
# actor 2 total 1 NILs 1 non-NILs
# John 2 total 0 NILs 2 non-NILs
# GG 2 total 2 NILs 0 non-NILs
# Lincoln 2 total 0 NILs 2 non-NILs
# DEMOCRAT 2 total 0 NILs 2 non-NILs
# girl 7 total 7 NILs 0 non-NILs
# asshole 3 total 1 NILs 2 non-NILs
# Vice President 4 total 3 NILs 1 non-NILs
# Gov 10 total 10 NILs 0 non-NILs
# creator 2 total 0 NILs 2 non-NILs
# loser 3 total 2 NILs 1 non-NILs
# candidate 6 total 2 NILs 4 non-NILs
# Governor 7 total 7 NILs 0 non-NILs
# editor 6 total 4 NILs 2 non-NILs
# Coanteen 2 total 2 NILs 0 non-NILs
# LauraKY 2 total 2 NILs 0 non-NILs
# National Guard 2 total 0 NILs 2 non-NILs
# Fox 2 total 0 NILs 2 non-NILs
# Athens 2 total 0 NILs 2 non-NILs
# chief 11 total 7 NILs 4 non-NILs
# Irish 2 total 0 NILs 2 non-NILs
# Congressman 2 total 1 NILs 1 non-NILs
# King 3 total 2 NILs 1 non-NILs
# Werderano 2 total 2 NILs 0 non-NILs
# soldier 4 total 4 NILs 0 non-NILs
# agent 2 total 2 NILs 0 non-NILs
# William Carson 2 total 2 NILs 0 non-NILs
# judge 6 total 5 NILs 1 non-NILs
# politician 3 total 0 NILs 3 non-NILs
# White House 2 total 0 NILs 2 non-NILs
# Korea 2 total 0 NILs 2 non-NILs
# mamallama 2 total 2 NILs 0 non-NILs
# governor 14 total 7 NILs 7 non-NILs
# contractor 3 total 2 NILs 1 non-NILs
# journalist 8 total 4 NILs 4 non-NILs
# whistleblower 3 total 0 NILs 3 non-NILs
# Beijing 2 total 0 NILs 2 non-NILs
# coward 2 total 1 NILs 1 non-NILs
# Nobody 2 total 2 NILs 0 non-NILs
# prophet 2 total 0 NILs 2 non-NILs
# suspect 5 total 5 NILs 0 non-NILs
# legislator 2 total 2 NILs 0 non-NILs
# ambassador 4 total 2 NILs 2 non-NILs
# Pope 3 total 2 NILs 1 non-NILs
# Ambassador 2 total 1 NILs 1 non-NILs
# Cameron 2 total 0 NILs 2 non-NILs
# writer 4 total 3 NILs 1 non-NILs
# PM 4 total 1 NILs 3 non-NILs
# gginnc 2 total 2 NILs 0 non-NILs
# Fry 2 total 2 NILs 0 non-NILs
# commentator 2 total 1 NILs 1 non-NILs
# director 10 total 6 NILs 4 non-NILs
# daughter 12 total 10 NILs 2 non-NILs
# NAACP 2 total 0 NILs 2 non-NILs
# prisoner 2 total 1 NILs 1 non-NILs
# fan 2 total 2 NILs 0 non-NILs
# killer 2 total 2 NILs 0 non-NILs
# boy 5 total 5 NILs 0 non-NILs
# murderer 2 total 2 NILs 0 non-NILs
# dealer 2 total 2 NILs 0 non-NILs
# investigator 2 total 2 NILs 0 non-NILs
# manager 6 total 6 NILs 0 non-NILs
# cop 2 total 2 NILs 0 non-NILs
# Dylann 2 total 2 NILs 0 non-NILs
# boss 4 total 1 NILs 3 non-NILs
# employee 4 total 4 NILs 0 non-NILs
# socialist 2 total 2 NILs 0 non-NILs
# lobbyist 2 total 2 NILs 0 non-NILs
# examiner 3 total 3 NILs 0 non-NILs
# donor 2 total 2 NILs 0 non-NILs
# Georgia 3 total 1 NILs 2 non-NILs
# clerk 2 total 2 NILs 0 non-NILs
# shit 2 total 2 NILs 0 non-NILs
# Sheriff 3 total 3 NILs 0 non-NILs
# CEO 4 total 2 NILs 2 non-NILs
# eu 2 total 0 NILs 2 non-NILs
# Attorney General 5 total 3 NILs 2 non-NILs
# vice president 4 total 3 NILs 1 non-NILs
# Wall Street 3 total 0 NILs 3 non-NILs
# child 2 total 2 NILs 0 non-NILs
# Director 4 total 3 NILs 1 non-NILs
# sister 5 total 5 NILs 0 non-NILs
# mom 3 total 3 NILs 0 non-NILs
# mother 13 total 12 NILs 1 non-NILs
# Freddie Gray 2 total 1 NILs 1 non-NILs
# Mosby 2 total 2 NILs 0 non-NILs
# Secretary 2 total 2 NILs 0 non-NILs
# prosecutor 2 total 1 NILs 1 non-NILs
# Master_Live 2 total 2 NILs 0 non-NILs
# RadecSupreme 2 total 2 NILs 0 non-NILs
# whipassmt 2 total 2 NILs 0 non-NILs
# Archbishop 2 total 1 NILs 1 non-NILs
# preacher 2 total 0 NILs 2 non-NILs
# jihadist 2 total 0 NILs 2 non-NILs
# Messiah 2 total 0 NILs 2 non-NILs
# Chairman 4 total 4 NILs 0 non-NILs
# bennett123 2 total 2 NILs 0 non-NILs
# hanuise 2 total 2 NILs 0 non-NILs
# Mediterranean 2 total 0 NILs 2 non-NILs
# Tunisian 2 total 1 NILs 1 non-NILs
# attacker 2 total 2 NILs 0 non-NILs
# Dame Pansi 2 total 2 NILs 0 non-NILs
# Euro 3 total 0 NILs 3 non-NILs
# Communist Party 2 total 0 NILs 2 non-NILs
# Chancellor 7 total 6 NILs 1 non-NILs
# Rick20967 2 total 2 NILs 0 non-NILs
# spokesman 12 total 12 NILs 0 non-NILs
# National Security Council 2 total 0 NILs 2 non-NILs
# SLAMMER0911 2 total 2 NILs 0 non-NILs
# Kenyan 2 total 0 NILs 2 non-NILs
# counterpart 3 total 0 NILs 3 non-NILs
# George Bush 2 total 0 NILs 2 non-NILs
# Bu bye Reid (montanaclass) 2 total 2 NILs 0 non-NILs
# student 6 total 6 NILs 0 non-NILs
# MENA 2 total 1 NILs 1 non-NILs
# Arab 2 total 0 NILs 2 non-NILs
# grandfather 5 total 4 NILs 1 non-NILs
# Sue Davey 2 total 2 NILs 0 non-NILs
# Charles Evans 2 total 2 NILs 0 non-NILs
# Suzanne 2 total 2 NILs 0 non-NILs
# GIGN 2 total 1 NILs 1 non-NILs
# Grandmaster 3 total 2 NILs 1 non-NILs
# grandmaster 2 total 1 NILs 1 non-NILs
# Author 2 total 1 NILs 1 non-NILs
# CVS 2 total 0 NILs 2 non-NILs
# Rev 12 total 12 NILs 0 non-NILs
# Rev. 4 total 4 NILs 0 non-NILs
# Hogan 5 total 5 NILs 0 non-NILs
# Luz 2 total 2 NILs 0 non-NILs
# Merabet 2 total 2 NILs 0 non-NILs
# Cherif Kouachi 2 total 2 NILs 0 non-NILs
# founder 4 total 3 NILs 1 non-NILs
# Brother 2 total 1 NILs 1 non-NILs
# House 2 total 0 NILs 2 non-NILs
# euro 2 total 0 NILs 2 non-NILs
# banker 2 total 1 NILs 1 non-NILs
# central bank 2 total 0 NILs 2 non-NILs
# diplomat 2 total 1 NILs 1 non-NILs
# tyrant 2 total 0 NILs 2 non-NILs
# reporter 3 total 2 NILs 1 non-NILs
# victim 3 total 3 NILs 0 non-NILs
# Lawrence W. 2 total 2 NILs 0 non-NILs
# Mary L. 2 total 2 NILs 0 non-NILs
# officer 17 total 16 NILs 1 non-NILs
# lawyer 3 total 3 NILs 0 non-NILs
# grandmother 4 total 3 NILs 1 non-NILs
# chairman 7 total 3 NILs 4 non-NILs
# resident 5 total 4 NILs 1 non-NILs
# Suspect 2 total 2 NILs 0 non-NILs
# Charb 2 total 1 NILs 1 non-NILs
# Charbonnier 2 total 1 NILs 1 non-NILs
# witness 4 total 1 NILs 3 non-NILs
# Prophet 5 total 4 NILs 1 non-NILs
# cartoonist 5 total 3 NILs 2 non-NILs
# Stéphane Charbonnier 2 total 1 NILs 1 non-NILs
# Bernard Verlhac 2 total 2 NILs 0 non-NILs
# Tignous 3 total 3 NILs 0 non-NILs
# Foreign Secretary 4 total 3 NILs 1 non-NILs
# attorney 4 total 4 NILs 0 non-NILs
# Williams 2 total 2 NILs 0 non-NILs
# pastor 5 total 3 NILs 2 non-NILs
# Eric Garner 2 total 2 NILs 0 non-NILs
# teenager 4 total 3 NILs 1 non-NILs
# Mourad 2 total 2 NILs 0 non-NILs
# brother-in-law 2 total 2 NILs 0 non-NILs
# 18-year-old 2 total 2 NILs 0 non-NILs
# driver 2 total 2 NILs 0 non-NILs
# Col. 2 total 2 NILs 0 non-NILs
# Capitol Hill 2 total 0 NILs 2 non-NILs
# bodyguard 2 total 2 NILs 0 non-NILs
# minister 3 total 2 NILs 1 non-NILs
# official 13 total 9 NILs 4 non-NILs
# imam 5 total 4 NILs 1 non-NILs
# Commissioner 3 total 3 NILs 0 non-NILs
# analyst 8 total 8 NILs 0 non-NILs
# survivor 2 total 2 NILs 0 non-NILs
# uncle 2 total 2 NILs 0 non-NILs
# Magistrate 2 total 2 NILs 0 non-NILs
# Johnson 2 total 2 NILs 0 non-NILs
# Riley 2 total 1 NILs 1 non-NILs
# Carson Cowles 2 total 2 NILs 0 non-NILs
# Emanuel African Methodist Episcopal Church 3 total 3 NILs 0 non-NILs
# the Netherlands 2 total 0 NILs 2 non-NILs
# source 4 total 4 NILs 0 non-NILs
# HSBC 2 total 0 NILs 2 non-NILs
# tourist 7 total 6 NILs 1 non-NILs
# mother-of-two 2 total 2 NILs 0 non-NILs
# husband 4 total 3 NILs 1 non-NILs
# Foreign Office 2 total 1 NILs 1 non-NILs
# strategist 4 total 4 NILs 0 non-NILs
# Rep. 9 total 9 NILs 0 non-NILs
# Morgan 2 total 2 NILs 0 non-NILs
# first lady 2 total 1 NILs 1 non-NILs
# dad 2 total 1 NILs 1 non-NILs
# Brooks 2 total 2 NILs 0 non-NILs
# Brown 2 total 1 NILs 1 non-NILs
# plumber 2 total 2 NILs 0 non-NILs
# economist 6 total 5 NILs 1 non-NILs
# spokesperson 2 total 2 NILs 0 non-NILs
# Secretary of Defense 2 total 2 NILs 0 non-NILs
# consultant 4 total 2 NILs 2 non-NILs
# successor 2 total 0 NILs 2 non-NILs
# associate 2 total 0 NILs 2 non-NILs
# Chief of Staff 2 total 2 NILs 0 non-NILs
# NSC 2 total 0 NILs 2 non-NILs
# Defense Secretary 2 total 2 NILs 0 non-NILs
# Monguno 2 total 1 NILs 1 non-NILs
# Major-General 4 total 4 NILs 0 non-NILs
# Commander 2 total 2 NILs 0 non-NILs
# Commandant 3 total 3 NILs 0 non-NILs
# Chief of Army Staff 5 total 5 NILs 0 non-NILs
# Majors General 2 total 2 NILs 0 non-NILs
# nephew 3 total 3 NILs 0 non-NILs
# Minister of Petroleum, Internal Affairs, Mines and Power 2 total 2 NILs 0 non-NILs
# House of Representatives 2 total 0 NILs 2 non-NILs
# Colonel 2 total 2 NILs 0 non-NILs
# army 2 total 0 NILs 2 non-NILs
# Major General 8 total 8 NILs 0 non-NILs
# Buratai 2 total 2 NILs 0 non-NILs
# Chief 2 total 1 NILs 1 non-NILs
# Economist 2 total 2 NILs 0 non-NILs
# Air Vice Marshal 2 total 2 NILs 0 non-NILs
# columnist 2 total 2 NILs 0 non-NILs
# worker 4 total 4 NILs 0 non-NILs
# Msgr 3 total 3 NILs 0 non-NILs
# spokeswoman 3 total 3 NILs 0 non-NILs
# Treasury 2 total 0 NILs 2 non-NILs
# dictator 2 total 1 NILs 1 non-NILs
# front-runner 2 total 0 NILs 2 non-NILs
# campaign manager 2 total 2 NILs 0 non-NILs
# Murphy 2 total 0 NILs 2 non-NILs
# native 2 total 2 NILs 0 non-NILs
# rival 3 total 0 NILs 3 non-NILs
# Sen 6 total 6 NILs 0 non-NILs
# fundraiser 2 total 1 NILs 1 non-NILs
# East Baltimore 2 total 1 NILs 1 non-NILs
# Man 2 total 1 NILs 1 non-NILs
# South China 2 total 2 NILs 0 non-NILs
# Minority Leader 2 total 2 NILs 0 non-NILs
# Columbiana Centre mall 2 total 2 NILs 0 non-NILs
# Midlands 2 total 0 NILs 2 non-NILs
# fiancee 2 total 2 NILs 0 non-NILs
# Evans 2 total 2 NILs 0 non-NILs
# author 3 total 2 NILs 1 non-NILs
# deputy 2 total 1 NILs 1 non-NILs
# SMART 2 total 2 NILs 0 non-NILs
# Shooter’s Choice 2 total 2 NILs 0 non-NILs
# Sir 2 total 2 NILs 0 non-NILs
# Smith 2 total 2 NILs 0 non-NILs
# data/edl2016_gold_data/data/tac_kbp_2016_edl_evaluation_gold_standard_entity_mentions.tab
# Count of docs per collection defaultdict(<class 'int'>, {'ENG': 7199, 'NYT': 2032})
# # Mentions of NILs =  1466
# # NIL clusters 999
# NOM only 91
# NAM only 826
# jkcerda 2 total 2 NILs 0 non-NILs
# country 19 total 0 NILs 19 non-NILs
# nation 7 total 1 NILs 6 non-NILs
# site 9 total 5 NILs 4 non-NILs
# body 5 total 0 NILs 5 non-NILs
# Apple 2 total 0 NILs 2 non-NILs
# Chinese 2 total 1 NILs 1 non-NILs
# ministry 5 total 2 NILs 3 non-NILs
# court 6 total 3 NILs 3 non-NILs
# son 5 total 3 NILs 2 non-NILs
# bridge 3 total 1 NILs 2 non-NILs
# group 9 total 1 NILs 8 non-NILs
# military 8 total 1 NILs 7 non-NILs
# mall 2 total 2 NILs 0 non-NILs
# fighter 5 total 1 NILs 4 non-NILs
# national 4 total 0 NILs 4 non-NILs
# European 2 total 0 NILs 2 non-NILs
# leekohler 2 total 2 NILs 0 non-NILs
# Moscow 2 total 0 NILs 2 non-NILs
# administration 3 total 0 NILs 3 non-NILs
# capital 11 total 0 NILs 11 non-NILs
# Apple Records 2 total 0 NILs 2 non-NILs
# building 14 total 13 NILs 1 non-NILs
# north 2 total 1 NILs 1 non-NILs
# Russia 2 total 0 NILs 2 non-NILs
# government 25 total 4 NILs 21 non-NILs
# rdowns 3 total 3 NILs 0 non-NILs
# Ukrainian 2 total 1 NILs 1 non-NILs
# company 13 total 3 NILs 10 non-NILs
# ucfgrad93 3 total 3 NILs 0 non-NILs
# New York 2 total 0 NILs 2 non-NILs
# venture 2 total 0 NILs 2 non-NILs
# house 4 total 2 NILs 2 non-NILs
# president 23 total 2 NILs 21 non-NILs
# forces 2 total 0 NILs 2 non-NILs
# city 21 total 1 NILs 20 non-NILs
# headquarters 4 total 3 NILs 1 non-NILs
# western 2 total 0 NILs 2 non-NILs
# shiva 2 total 2 NILs 0 non-NILs
# store 8 total 7 NILs 1 non-NILs
# giant 3 total 0 NILs 3 non-NILs
# scottishcelts 2 total 2 NILs 0 non-NILs
# guy 9 total 3 NILs 6 non-NILs
# Europe 2 total 0 NILs 2 non-NILs
# Bush 2 total 0 NILs 2 non-NILs
# one 19 total 6 NILs 13 non-NILs
# sir 2 total 1 NILs 1 non-NILs
# factory 11 total 11 NILs 0 non-NILs
# man 9 total 3 NILs 6 non-NILs
# airport 3 total 0 NILs 3 non-NILs
# department 3 total 1 NILs 2 non-NILs
# Snowden 2 total 0 NILs 2 non-NILs
# Soviet Union 2 total 0 NILs 2 non-NILs
# Ma 2 total 1 NILs 1 non-NILs
# iJohnHenry 2 total 2 NILs 0 non-NILs
# Western 2 total 0 NILs 2 non-NILs
# director 8 total 5 NILs 3 non-NILs
# Gudi 2 total 2 NILs 0 non-NILs
# party 13 total 0 NILs 13 non-NILs
# the Beatles 2 total 0 NILs 2 non-NILs
# BUILDING 2 total 2 NILs 0 non-NILs
# state 13 total 1 NILs 12 non-NILs
# Rana Plaza 6 total 6 NILs 0 non-NILs
# wife 6 total 4 NILs 2 non-NILs
# Government 8 total 2 NILs 6 non-NILs
# square 4 total 2 NILs 2 non-NILs
# commander 3 total 2 NILs 1 non-NILs
# agency 10 total 0 NILs 10 non-NILs
# Happybunny 3 total 3 NILs 0 non-NILs
# President 6 total 0 NILs 6 non-NILs
# mother 2 total 1 NILs 1 non-NILs
# fixyourthinking 2 total 2 NILs 0 non-NILs
# Board 2 total 2 NILs 0 non-NILs
# dad 2 total 2 NILs 0 non-NILs
# hotel 2 total 2 NILs 0 non-NILs
# America 2 total 0 NILs 2 non-NILs
# Defense 2 total 1 NILs 1 non-NILs
# home 11 total 7 NILs 4 non-NILs
# business 5 total 4 NILs 1 non-NILs
# Catapult 2 total 2 NILs 0 non-NILs
# MacRumors 18 total 17 NILs 1 non-NILs
# Parliament 4 total 1 NILs 3 non-NILs
# branch 3 total 3 NILs 0 non-NILs
# space 2 total 1 NILs 1 non-NILs
# board 3 total 3 NILs 0 non-NILs
# area 8 total 6 NILs 2 non-NILs
# Amazulu 3 total 3 NILs 0 non-NILs
# region 8 total 0 NILs 8 non-NILs
# district 5 total 1 NILs 4 non-NILs
# leader 17 total 1 NILs 16 non-NILs
# activist 4 total 2 NILs 2 non-NILs
# State 6 total 1 NILs 5 non-NILs
# father 4 total 0 NILs 4 non-NILs
# side 3 total 1 NILs 2 non-NILs
# coast 3 total 3 NILs 0 non-NILs
# bank 7 total 3 NILs 4 non-NILs
# founder 3 total 0 NILs 3 non-NILs
# apple 2 total 0 NILs 2 non-NILs
# premises 2 total 2 NILs 0 non-NILs
# Terminal F 2 total 2 NILs 0 non-NILs
# Zorlu Center 5 total 5 NILs 0 non-NILs
# structure 2 total 2 NILs 0 non-NILs
# manufacturer 3 total 0 NILs 3 non-NILs
# official 14 total 10 NILs 4 non-NILs
# terrorist 4 total 0 NILs 4 non-NILs
# monitor 2 total 1 NILs 1 non-NILs
# National 7 total 0 NILs 7 non-NILs
# friend 8 total 7 NILs 1 non-NILs
# coastal 2 total 2 NILs 0 non-NILs
# Zhao Jiemin 4 total 4 NILs 0 non-NILs
# firm 2 total 0 NILs 2 non-NILs
# member 13 total 5 NILs 8 non-NILs
# Samar 2 total 0 NILs 2 non-NILs
# border 5 total 3 NILs 2 non-NILs
# dictator 2 total 0 NILs 2 non-NILs
# spokesman 9 total 5 NILs 4 non-NILs
# head 10 total 3 NILs 7 non-NILs
# alset 2 total 2 NILs 0 non-NILs
# lawyer 8 total 6 NILs 2 non-NILs
# prison 4 total 4 NILs 0 non-NILs
# neighbor 2 total 0 NILs 2 non-NILs
# judge 3 total 1 NILs 2 non-NILs
# Ricekila 4 total 4 NILs 0 non-NILs
# supplier 2 total 0 NILs 2 non-NILs
# NY 2 total 0 NILs 2 non-NILs
# astronaut 2 total 1 NILs 1 non-NILs
# Leslie 2 total 2 NILs 0 non-NILs
# parliament 5 total 1 NILs 4 non-NILs
# 10 Bears 2 total 2 NILs 0 non-NILs
# diplomat 2 total 0 NILs 2 non-NILs
# office 4 total 3 NILs 1 non-NILs
# hero 3 total 0 NILs 3 non-NILs
# poster 2 total 2 NILs 0 non-NILs
# Cabinet 2 total 0 NILs 2 non-NILs
# chief 7 total 1 NILs 6 non-NILs
# Millhouse 4 total 4 NILs 0 non-NILs
# secretary 2 total 0 NILs 2 non-NILs
# Foreign Ministry 2 total 0 NILs 2 non-NILs
# Renzatic 2 total 2 NILs 0 non-NILs
# spot 2 total 1 NILs 1 non-NILs
# opposition 3 total 0 NILs 3 non-NILs
# Meow 2 total 2 NILs 0 non-NILs
# center 6 total 4 NILs 2 non-NILs
# successor 2 total 0 NILs 2 non-NILs
# owner 3 total 2 NILs 1 non-NILs
# Jimmy 2 total 0 NILs 2 non-NILs
# professor 5 total 2 NILs 3 non-NILs
# division 4 total 3 NILs 1 non-NILs
# Washington 2 total 0 NILs 2 non-NILs
# King 2 total 0 NILs 2 non-NILs
# designer 3 total 2 NILs 1 non-NILs
# bureau 2 total 2 NILs 0 non-NILs
# police 5 total 2 NILs 3 non-NILs
# Pentagon 2 total 0 NILs 2 non-NILs
# Boomhauer 3 total 3 NILs 0 non-NILs
# army 3 total 0 NILs 3 non-NILs
# eagandale4114 2 total 2 NILs 0 non-NILs
# huangyanan 6 total 6 NILs 0 non-NILs
# BornAgainMac 2 total 2 NILs 0 non-NILs
# part 4 total 3 NILs 1 non-NILs
# MacVista 2 total 2 NILs 0 non-NILs
# university 3 total 1 NILs 2 non-NILs
# Alexandria 2 total 0 NILs 2 non-NILs
# the beatles 2 total 0 NILs 2 non-NILs
# zone 2 total 2 NILs 0 non-NILs
# Dick Dasterdly 2 total 2 NILs 0 non-NILs
# source 6 total 3 NILs 3 non-NILs
# whistleblower 2 total 0 NILs 2 non-NILs
# NorthernLad 2 total 2 NILs 0 non-NILs
# idiot 2 total 1 NILs 1 non-NILs
# Abbey Lane 2 total 1 NILs 1 non-NILs
# Apple records 2 total 0 NILs 2 non-NILs
# prudens-entis 2 total 2 NILs 0 non-NILs
# retailer 2 total 0 NILs 2 non-NILs
# unit 3 total 2 NILs 1 non-NILs
# expert 4 total 3 NILs 1 non-NILs
# Red Cross 2 total 0 NILs 2 non-NILs
# Hero 2 total 0 NILs 2 non-NILs
# marwa2 2 total 2 NILs 0 non-NILs
# administrator 2 total 2 NILs 0 non-NILs
# town 3 total 0 NILs 3 non-NILs
# minister 16 total 2 NILs 14 non-NILs
# officer 3 total 2 NILs 1 non-NILs
# KeyboardKommando 2 total 2 NILs 0 non-NILs
# place 5 total 1 NILs 4 non-NILs
# Tilpots 2 total 2 NILs 0 non-NILs
# engineer 2 total 2 NILs 0 non-NILs
# skunk 3 total 3 NILs 0 non-NILs
# street 2 total 2 NILs 0 non-NILs
# The Beatles 2 total 0 NILs 2 non-NILs
# force 3 total 1 NILs 2 non-NILs
# location 6 total 5 NILs 1 non-NILs
# John.B 2 total 2 NILs 0 non-NILs
# executive 3 total 0 NILs 3 non-NILs
# station 3 total 2 NILs 1 non-NILs
# Vendome 2 total 2 NILs 0 non-NILs
# daughter 2 total 2 NILs 0 non-NILs
# reporter 2 total 2 NILs 0 non-NILs
# economist 2 total 1 NILs 1 non-NILs
# manager 2 total 1 NILs 1 non-NILs
# province 3 total 0 NILs 3 non-NILs
# Mogli 2 total 2 NILs 0 non-NILs
# LIVEFRMNYC 2 total 2 NILs 0 non-NILs
# swingerofbirch 2 total 2 NILs 0 non-NILs
# Finance 2 total 0 NILs 2 non-NILs
# maflynn 3 total 3 NILs 0 non-NILs
# someone 2 total 1 NILs 1 non-NILs
# Beatles 2 total 0 NILs 2 non-NILs
# road 2 total 1 NILs 1 non-NILs
# cabinet 3 total 0 NILs 3 non-NILs
# representative 4 total 3 NILs 1 non-NILs
# person 3 total 0 NILs 3 non-NILs
# husband 4 total 4 NILs 0 non-NILs
# resident 4 total 3 NILs 1 non-NILs
# UKCityGent 2 total 2 NILs 0 non-NILs
# Coast 2 total 2 NILs 0 non-NILs
# plant 2 total 2 NILs 0 non-NILs
# Jessica Lares 2 total 2 NILs 0 non-NILs
# Beaverstate 3 total 3 NILs 0 non-NILs
# newspaper 3 total 0 NILs 3 non-NILs
# Governor 2 total 1 NILs 1 non-NILs
# dude 2 total 2 NILs 0 non-NILs
# figure 2 total 0 NILs 2 non-NILs
# land 2 total 0 NILs 2 non-NILs
# organization 4 total 0 NILs 4 non-NILs
# Air Force 2 total 0 NILs 2 non-NILs
# Wife 2 total 2 NILs 0 non-NILs
# fellow 2 total 0 NILs 2 non-NILs
# northeast 2 total 1 NILs 1 non-NILs
# republic 2 total 0 NILs 2 non-NILs
# GoCubsGo 2 total 2 NILs 0 non-NILs
# Rogifan 3 total 3 NILs 0 non-NILs
# Scepticalscribe 2 total 2 NILs 0 non-NILs
# partner 3 total 0 NILs 3 non-NILs
# fat jez 2 total 2 NILs 0 non-NILs
# Rocketman 2 total 2 NILs 0 non-NILs
# spokesperson 3 total 3 NILs 0 non-NILs
# desert 2 total 0 NILs 2 non-NILs
# president-elect 2 total 0 NILs 2 non-NILs
# Dad 2 total 2 NILs 0 non-NILs
# Brits_abroad 2 total 2 NILs 0 non-NILs
# BrainGlutton 2 total 2 NILs 0 non-NILs
# sea 2 total 0 NILs 2 non-NILs
# maker 2 total 1 NILs 1 non-NILs
# papilon 2 total 2 NILs 0 non-NILs
# governor 4 total 2 NILs 2 non-NILs
# White House 3 total 0 NILs 3 non-NILs
# East Coast Woods 2 total 2 NILs 0 non-NILs
# encampment 3 total 3 NILs 0 non-NILs
# House 2 total 0 NILs 2 non-NILs
# mayor 3 total 2 NILs 1 non-NILs
# Steve28 2 total 2 NILs 0 non-NILs
# parliamentary 2 total 0 NILs 2 non-NILs
# macs4nw 2 total 2 NILs 0 non-NILs
# statesman 2 total 0 NILs 2 non-NILs
# Bloomberg 2 total 0 NILs 2 non-NILs
# chairman 4 total 0 NILs 4 non-NILs
# rest 2 total 2 NILs 0 non-NILs
# suburb 2 total 1 NILs 1 non-NILs
# OleJanx 2 total 2 NILs 0 non-NILs
# interior 2 total 0 NILs 2 non-NILs
# Cuban Missles 3 total 3 NILs 0 non-NILs
# Army 2 total 0 NILs 2 non-NILs
# jackytoo 2 total 2 NILs 0 non-NILs
# mikelincs 2 total 2 NILs 0 non-NILs
# CEO 3 total 0 NILs 3 non-NILs
# king 3 total 0 NILs 3 non-NILs
# scot47 3 total 3 NILs 0 non-NILs
# Domino 2 total 2 NILs 0 non-NILs
# apartment 2 total 2 NILs 0 non-NILs
# apple records 2 total 0 NILs 2 non-NILs
# Rabaa al-Adawiya 2 total 0 NILs 2 non-NILs
# ambassador 4 total 4 NILs 0 non-NILs
# MICA 2 total 2 NILs 0 non-NILs
# heart 2 total 2 NILs 0 non-NILs
# commissioner 2 total 0 NILs 2 non-NILs
# LEADER 2 total 0 NILs 2 non-NILs
# dumastudetto 2 total 2 NILs 0 non-NILs
# journalist 2 total 1 NILs 1 non-NILs
# MIL-DOT 2 total 2 NILs 0 non-NILs
# consulate 2 total 2 NILs 0 non-NILs
# Shrink 2 total 2 NILs 0 non-NILs
# woman 2 total 1 NILs 1 non-NILs
# Slats 2 total 2 NILs 0 non-NILs
# Liberal 2 total 2 NILs 0 non-NILs
# Naim 3 total 3 NILs 0 non-NILs
# phrehdd 2 total 2 NILs 0 non-NILs
# committee 2 total 2 NILs 0 non-NILs
# D 2 total 1 NILs 1 non-NILs
# neighborhood 2 total 1 NILs 1 non-NILs
# counterpart 2 total 0 NILs 2 non-NILs
# carlgo 2 total 2 NILs 0 non-NILs
# snberk103 2 total 2 NILs 0 non-NILs
# Marxist 2 total 0 NILs 2 non-NILs
# Fred 2 total 2 NILs 0 non-NILs
# floor 2 total 2 NILs 0 non-NILs
# laureate 2 total 0 NILs 2 non-NILs
# analyst 2 total 2 NILs 0 non-NILs
# gov. 2 total 0 NILs 2 non-NILs
# facility 2 total 1 NILs 1 non-NILs
# south 2 total 0 NILs 2 non-NILs
# mrkramer 2 total 2 NILs 0 non-NILs
# kmussack 2 total 2 NILs 0 non-NILs
# worker 2 total 2 NILs 0 non-NILs
# camp 4 total 3 NILs 1 non-NILs
# advisor 2 total 1 NILs 1 non-NILs
# roadbloc 3 total 3 NILs 0 non-NILs
# UNITED NATIONS 2 total 0 NILs 2 non-NILs
# govt 2 total 0 NILs 2 non-NILs
# Ambrose Chapel 2 total 2 NILs 0 non-NILs
# rescuer 2 total 2 NILs 0 non-NILs
# boy 2 total 2 NILs 0 non-NILs
# soldier 2 total 1 NILs 1 non-NILs
# mikrofon 2 total 2 NILs 0 non-NILs
# embassy 2 total 0 NILs 2 non-NILs
