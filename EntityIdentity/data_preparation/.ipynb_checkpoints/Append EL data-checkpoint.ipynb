# %% [markdown]
# # Expansion against existing EL corpora

# %%
import pickle
import glob

# %% [markdown]
# ### 1) Get all names in GVA

# %%
input_path='../data/input'

gva_input_annotations_file = '%s/annotation/participants_input.p' % input_path
with open(gva_input_annotations_file, 'rb') as f:
    gva_input_annotations = pickle.load(f)

# %%
all_names=set()
names_list=[]
for doc_id, data in gva_input_annotations.items():
    for participant_id, participant_info in data.items():
        if 'Name' in participant_info:
            all_names.add(participant_info['Name'])
            names_list.append(participant_info['Name'])

# %%
len(all_names)
# Out:
# 456

# %%
from collections import Counter

cntr=Counter(names_list).most_common()

# %% [markdown]
# ### Find incidents for a participant

# %%
import json

with open ('%s/str_data.json' % input_path) as f:
    str_data=json.load(f)

# %%
for participant_name, freq in cntr:
    participant_name=participant_name.strip()
    incs=set()
    for inc, parts in str_data.items():
        for part in parts:
            if 'Name' in part and part['Name'].strip()==participant_name:
                incs.add(inc)
    if len(incs)>1:
        print(participant_name, incs)
# Out:
#  Lonato Moran-Allen
#  Jaxon Slaight
#  Joseph Slaight
#  Morgan Slaight
#  Devon Lofton
#  Vincent Wainwright
#  Brady Osborne
#  Matt Anderson
#  Jessica Rosales
#  Pedro Rosales
#  Jonathon Walker
#  Viola Walker
#  Shantai Hale
#  Kayla Walker
#  Ezequiel Melendez
#  Makayla Manners
#  Corinne Horn
#  Thomas Horn
#  Joseph Horn
#  Justin Burns
#  Edmundo Amaro-Bajonero
#  Katie Gildersleeve
#  Ruben Rigoberto-Reyes
#  Brenda Dolan
#  Madelyn Rychetski
#  Steven Dolan
#  Paxton Shannon
#  Gavin Stiles
#  Erica Robinson
#  Jahad Brumsey
#  Dennis Warren
#  Kiyan Shelton
#  Mariah Davis
#  DaMontez Jones
#  Henry Jackson
#  Stanley Greene
#  Carl Johnson
#  Thomas Kamp
#  Austin Kamp
#  Nathan Kamp
#  Kade Johnson
#  Hannah Johnson
#  Da’Vaughn Pitts
#  Christopher Moran
#  Sean Strickland
#  Jeremy Taylor
#  Kodi Pruner
#  Jahliek Dieudonne
#  Cynthia Morris
#  Breanna Pavilicek
#  Ava Castillo
#  Javon Wilson
#  Luke Smith
#  Breyona McMillian
#  Sharon Lander
#  Journi Johnson
#  Aavaire Johnson
#  Shawn Johnson
#  Eric Summerfield
#  Bernie Porche
#  Calvin Dawayne Powers
#  Tyler Jordan Buchanan
#  Christopher Roupe
#  Braison Howard
#  Briar Newsome
#  Clarance Washington
#  Olivia Washington
#  Onya Washington
#  Omesha Washington
#  Shauna Washington
#  Matthew Regula
#  Darin Booker
#  Hayden Mayes
#  Jacob Stahl
#  Austin Hedrick
#  Jaden Rahm
#  Liesel Casto
#  Kaleb Ahles
#  Mark Mata
#  Hank Mata
#  Min Huang
#  Michael Strickland
#  Patrick MacFarlane
#  Ryan Korish
#  Ilanye Price
#  Kevin Pimentel
#  Brady Pimentel
#  Trevor Pimentel
#  Jaxon White
#  Kristen Williams
#  Jatarius Tolbert
#  Jacob Melendez
#  Marques Green
#  Bobby McCullough
#  Blake Smith
#  Tylee Smith
#  Shawna Smith
#  Russell Smith
#  Sofia Chiddo
#  Xavier Neff
#  Elizabeth Flores
#  Jonathan Kaufman
#  Ja'Don Johnson
#  Mark Weekly
#  Meredith Jessie
#  Marquise Frederick
#  Shawn Fuller
#  Josiah Fuller
#  Uriah Fuller
#  Ty Conly
#  Carter Epps
#  Dannielle Rangel
#  Michael Westerhuis
#  Connor Westerhuis
#  Jaeci Westerhuis
#  Kailey Westerhuis
#  Scott Westerhuis
#  Colin Brough
#  Kyle Markins
#  Veronica Mercado
#  Linette Cano
#  Maleki Parker
#  Zion Willis
#  Christopher Garcia
#  Dronald Washington
#  Kaitlyn Pullam
#  Rebeika Powell
#  Kayetie Melchor
#  Misty Nunley
#  Julie Jackson
#  Kiana Welch
#  Maria Nash
#  Kem Delaney
#  Ronald Roberts
#  Devin Anderson
#  Andrew Carroll
#  James Baker
#  Nicholas Ursiny
#  Jayden Choate
#  Eric Zavala
#  Mahsaan Kelley-Wilson
#  Sani Holmes
#  Anna Sanchez
#  Travon Rollins
#  Erica Rodriguez
#  Paula Nino
#  Alejandro Rodriguez
#  Lorena Nino
#  Alejandro Martinez
#  Xavier Lucero-Waters
#  Moses Waters
#  Kenneth Murphy
#  Karmelo Johnson
#  Wyatt Whitaker
#  King Carter
#  Kaitlynn O'Donahue
#  Christopher Griffith
#  Tavaris Rhodes
#  Jaiden DeLeon
#  Kenny Kreuscher
#  Sara Atkinson
#  Destiny Bargman
#  Ja'Terreon Thorne
#  Justice Galarza
#  Dekota Smith
#  Maurice Phillips
#  Tahirah Phillips
#  Holston Cole
#  Devon Bohn
#  Paige Bohn
#  Justin Bohn
#  Bryant Sanchez
#  Cheyanne Green
#  Peter Noack
#  Jon’tayasia Dillon-White
#  Quanisha Sims
#  Steafon Lewis
#  Ackeem Davis
#  John Casullo
#  Kathleen Casullo
#  James Casullo
#  Christian Bandemer
#  Owen Hicks
#  Cody Thorneberry
#  Antwonia Heyward
#  Brandon Lemar Greene
#  Omar Hamilton
#  Daniel Munoz
#  Allen Troyer
#  William Mitchell Hudson
#  Orlando Collins
#  Luis Canseco
#  Robert Hutton
#  Lydell McLaurin
#  Jeremy Mushrush
#  Lance Buckley
#  Amy Buckley
#  Claire Buckley
#  Abigail Buckley
#  Sharae Thompson
#  Xander Thompson
#  Zackary Yashkus
#  Saeve Evans
#  Teagan Hutton
#  Emily McDonald
#  McKay Hutton
#  Herbert Lattin
#  John Lander
#  Dana Remaley
#  Caleb Remaley
#  Roxanne Shipman
#  Fabriccio Patti
#  Angela Hernandez
#  Jaibreon Cook
#  Chet Hockman
#  Nautica Whittiker
#  Gary Holmes
#  Herbert Harr
#  Carina Mancera
#  Jennabel Anaya
#  Michael Parsons
#  Ibram Hanna
#  Coleton Weatherford
#  Blake Shurling
#  Jacob Setter
#  Marsavious Frazier
#  Joshua Guzman
#  Tyre King
#  Ryan Mayhew
#  Diego Gomez-Martinez
#  Samantha Burnette
#  Melanie Martinez
#  Samaya Copeland
#  Christopher Andrews
#  Tristan Carr
#  Keagan Schweikle
#  Prentiss Jackson
#  Gina Williams
#  Nathaniel Jones
#  E.C. Robinson
#  Kendall Reed
#  Will Harris
#  Steven Coleman
#  Emmanuel Arrington
#  Sieyumbe Arrington
#  Cristobal Guerroro
#  Anthony Heard
#  Kyle Carney
#  Curtis Hollinger
#  Galen Hawk
#  Christina Walker
#  Katherine Obukhov
#  Elizabeth Obukhov
#  Nina Obukhov
#  Carlos Stokes
#  Branden Brookins
#  Jordan Clayton
#  Bentley Lenhart
#  Tyderris Cash
#  DeShawn Beedles
#  Nilda Sheffield
#  Amari Brown
#  Lily Coats-Nichols
#  Cheyenne Jessie
#  Jemini Smith
#  Devin Callahan
#  Quamari McAllister
#  Winston Brown
#  Barry Washington
#  Timothy Murphy
#  Nicole Westerhuis
#  Alexis Church
#  Colleen Church
#  Steven Jones
#  Kyle Zientek
#  Sharia Lynch
#  David Provencio
#  Tristan Fenton
#  Blayden Ashley
#  Eron Burks
#  Amar Chisler
#  Dametrious Addison
#  Elijah Hoffman
#  Rachael Johnson
#  Raheem Shannon
#  Marcus Seichter
#  James Poore
#  Cedric Poore
#  Rosalba Velazquez
#  Ahmad Antoine
#  Jamyha Luss
#  Bryson Hernandez
#  Riley Brooks-Owings
#  Dewaun Rockingham
#  Oliver Kennedy
#  Alac Jackson
#  Stephen Brumby
#  Ava Chadderdon
#  Edgar Padilla
#  Nelven Salas
#  Davon Coleman
#  Barry Moore
#  Pamela Moore
#  Tristan Crayton
#  Gabriel Daniels
#  Raymond Williams
#  Andrew Allen
#  Taylor McCormick
#  Sidresha Lamb
#  Ronald Smith
#  Nijia Ward
#  Albert Dickerson
#  Ivette Sterling
#  Adrian Bennett
#  Isaiah Deloatch
#  Lavardo Fisher
#  Aubrey Davis
#  Alan Martinez
#  Joe Knarr
#  Daniel Knarr
#  Jen Knarr
#  Brennan Weikel
#  Queshandis Seals
#  Christian Merced
#  Jacob Pulliam
#  Mekko Stumblingbear
#  Gladys Tordil
#  Claudina Molina
#  Malcolm Winffel
#  Colin Fraley
#  Anthony Mendoza
#  Codie Powell
#  Donald Powell
#  Montez Brown
#  Anthony Shannon
#  Henry Brown
#  Marcus Cole Holt
#  Tyquone Greer
#  Ismael Moreno Jr.
#  Jamar Hamilton
#  Darron Daniels
#  Maurice Kelley
#  DaVaughn Pitts
#  LaChristopher Pettway
#  Ronald Williams
#  Kendra Hill
#  Veronica Hernandez
#  Yosselyn Alfaro
#  Michael Adams
#  Chris Flaker
#  Miguel Maldonado
#  Oscar Delgado
#  Darell Brown
#  Antonyo Demarlo-Jennings
#  Dominique Davis
#  Stephaun Gaston
#  Vashon Dukes
#  Whitney Lewis
#  Shawn Adams
#  Natasha Stewart
#  Darius Gulley
#  Linquinton Dean
#  Freddy Duhart
#  Christopher Cadenbach
#  Owen Cadenbach
#  Ethan Cadenbach
#  Ismail Majid
#  Justin Malone
#  Caden Randolph
#  Linda Hutton
#  James Graham
#  Jacob Remaley
#  Christopher Brandon-Lucket
#  A'yanna Allan
#  Tyanna Thomas
#  Mickey Collins
#  Janet Francois
#  Oliver Portieles
#  Melanie Johnson
#  Martaouse Holloway
#  Christopher Chaney
#  Willie Norman
#  Nicholette Briscoe
#  Kelcii Flintroy
#  Rashawn Gibson
#  Bruce Stevens
#  Sarah Bonner
#  Hunter Richardson
#  Jaylen Pender
#  Thomas Guitierrez
#  Daylee Newman
#  Brandon Colbert
#  Thomas Meisenheimer
#  Walter Meisenheimer
#  Thomas Lane
#  Cade Hartwig
#  Emiko Diaz
#  Jesus Diaz
#  Jayden Norton
#  Jada Page
#  Dakota Schriefer
#  Treyvon Tyson
#  Wakeel Stewart
#  Maurice Bellamy
#  Tyree Johnson
#  Darryl Freeman
#  Al McCraig
#  Ava Schowalter
#  Dalon Williams
#  Amaya Shafi
#  Amirra Jacques
#  Anthony Ellison
#  DeAndre Foster
#  Kondrea Wilson
#  Cornell Dunn
#  Fabian McIntyre
#  Jaquwaivyon Mattes
#  Mike Smith
#  Brittany Rock
#  Christopher Calloway
#  Kalisha Smith
#  Davonte Bobo
#  Allen Ramsey
#  Justice Burroughs
#  Katylin Bellamy
#  Kristina Burroughs
#  Keith Davis
#  David Bettancourt
#  Shady Al-Hussien
#  Kyle Sheriff
#  Jesus Valencia
#  Melani Valencia
#  Jael Valencia
#  Chad Couture
#  Dan Caron
#  Morris Charpentier
#  Rakim Watson
#  Charles Jackson
#  Daquarius Tucker
#  Gerald Sykes
#  Jerome Rankin
#  Tedashi Williams
#  Kadejah Williams
#  Cole Kirkpatrick
#  Scott Travis Thompson
#  Lawrence Anderson
#  Daniel Wright
#  Eduardo Trejo
#  Jonathan Martinez
#  Derric Hall
#  Justin Anderson
#  Billy Williams
#  Larry Lynch
#  David Krauss
#  Wyatt Krauss
#  Monica Valdez

# %% [markdown]
# ### 2) Check for overlaps in EL datasets

# %%
def check_overlap(keys):
    results=set()
    for c in glob.glob('el_corpora/*.tsv'):
        print(c)
        with open(c, 'r') as rc:
            for line in rc:
                splits=line.split('\t')
                if splits[0].strip() in keys:
                    results.add(tuple([c, splits[0], splits[1]]))
    return results

# %%
result=check_overlap(all_names) # are full entity names found
result
# Out:
# el_corpora/AIDA-YAGO2_entities_and_links.tsv
# el_corpora/neel2015-test.tsv
# el_corpora/neel2014-test.tsv
# el_corpora/oke.tsv
# el_corpora/neel2014-train.tsv
# el_corpora/rss500-unicode.tsv
# el_corpora/wikinews.tsv
# el_corpora/wes2015.tsv
# el_corpora/neel2015-train.tsv
# el_corpora/neel2014.tsv
# el_corpora/rss500.tsv
# el_corpora/neel2015.tsv
# el_corpora/oke-testset.tsv
# el_corpora/neel2015-dev.tsv
# el_corpora/oke-trainingset.tsv
# set()
